# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.616428
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.1%
# Minibatch loss at step 50: 1.449544
# Minibatch accuracy: 56.2%
# Validation accuracy: 56.2%
# Minibatch loss at step 100: 0.938274
# Minibatch accuracy: 62.5%
# Validation accuracy: 69.2%
# Minibatch loss at step 150: 0.380058
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 200: 0.859059
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 0.991632
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 300: 0.408690
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 350: 0.613621
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 400: 0.213840
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 0.897275
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 500: 0.756381
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 550: 0.937465
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 600: 0.377117
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.945175
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 700: 0.915682
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 750: 0.099885
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 800: 0.654908
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 850: 0.827142
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 900: 0.779308
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 950: 0.520969
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.441841
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Test accuracy: 89.2%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %% [markdown]
# ## *Answer 1 -- max pooling*

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
            [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
            [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
            [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
            [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding ='SAME')
        hidden = tf.nn.relu(pooled + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding ='SAME')
        hidden = tf.nn.relu(pooled + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
    
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                    valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.439826
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.930462
# Minibatch accuracy: 18.8%
# Validation accuracy: 32.2%
# Minibatch loss at step 100: 1.267597
# Minibatch accuracy: 56.2%
# Validation accuracy: 61.5%
# Minibatch loss at step 150: 0.774598
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.1%
# Minibatch loss at step 200: 0.906642
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 1.258100
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 300: 0.447386
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 350: 0.537080
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.0%
# Minibatch loss at step 400: 0.181799
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 450: 0.779334
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 0.623248
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 550: 0.845869
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 600: 0.330701
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 650: 0.933289
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 700: 0.861272
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 750: 0.044669
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 800: 0.477327
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 850: 0.736000
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 900: 0.542122
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 950: 0.572848
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 1000: 0.637377
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# ## *Answer 2 -- deep CNN (LeNet5) *

# %%
batch_size = 64
num_epochs = 10
patch_size = 5
depth = 16
num_hidden = 128
train_size = train_dataset.shape[0]
#num_hidden_2 = 120

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
            [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
            [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
            [(image_size // 4) * (image_size // 4) * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
            [num_hidden, num_hidden], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer5_weights = tf.Variable(tf.truncated_normal(
            [num_hidden, num_labels], stddev=0.1))
    layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data, train=False):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding = 'SAME')
        hidden = tf.nn.relu(pool + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding = 'SAME')
        pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding = 'SAME')
        hidden = tf.nn.relu(pool + layer2_biases)
        
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1]*shape[2]*shape[3]])
        
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        if train:
            hidden = tf.nn.dropout(hidden, 0.5)
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        if train:
            hidden = tf.nn.dropout(hidden, 0.5)
        return tf.matmul(hidden, layer5_weights) + layer5_biases
        
    # Training computation.
    logits = model(tf_train_dataset, train = True)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    regularizer = tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer5_weights)
    loss = loss + 5e-4*regularizer
    
    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learning_rate = tf.train.exponential_decay(0.05, global_step*batch_size, train_size, 0.95)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
    
num_steps = train_size*num_epochs // batch_size

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                    valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.665874
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.3%
# Minibatch loss at step 500: 0.833431
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 1000: 0.737584
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.0%
# Minibatch loss at step 1500: 0.881986
# Minibatch accuracy: 73.4%
# Validation accuracy: 85.3%
# Minibatch loss at step 2000: 0.624469
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# Minibatch loss at step 2500: 0.706733
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 3000: 0.751473
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# Minibatch loss at step 3500: 0.635702
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 4000: 0.779040
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 4500: 0.523892
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 5000: 0.726929
# Minibatch accuracy: 76.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 5500: 0.749783
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 6000: 0.503123
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 6500: 0.396880
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 7000: 0.500939
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.4%
# Minibatch loss at step 7500: 0.645938
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 8000: 0.617494
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 8500: 0.913714
# Minibatch accuracy: 79.7%
# Validation accuracy: 88.6%
# Minibatch loss at step 9000: 0.395659
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 9500: 0.532176
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 10000: 0.448283
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 10500: 0.615462
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 11000: 0.454062
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 11500: 0.582005
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 12000: 0.595349
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 12500: 0.304315
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 13000: 0.591586
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 13500: 0.327383
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 14000: 0.422823
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 14500: 0.440838
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 15000: 0.498272
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 15500: 0.437118
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 16000: 0.434852
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 16500: 0.437311
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 17000: 0.506396
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 17500: 0.520833
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 18000: 0.542918
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 18500: 0.439639
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 19000: 0.516980
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 19500: 0.459506
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 20000: 0.286742
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 20500: 0.559005
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 21000: 0.616306
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 21500: 0.420519
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 22000: 0.338591
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 22500: 0.466431
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 23000: 0.463890
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 23500: 0.560768
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 24000: 0.862060
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.8%
# Minibatch loss at step 24500: 0.588282
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.2%
# Minibatch loss at step 25000: 0.684868
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 25500: 0.320639
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 26000: 0.409353
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 26500: 0.513854
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 27000: 0.583903
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 27500: 0.600093
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 28000: 0.565152
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 28500: 0.439691
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 29000: 0.255867
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 29500: 0.497693
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 30000: 0.327722
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 30500: 0.473493
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.6%
# Minibatch loss at step 31000: 0.390168
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Test accuracy: 96.0%
